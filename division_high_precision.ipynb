# %%
from decimal import Decimal, getcontext
import math
import mpmath


print("1 / 243 = ? ")

## Decimal:
getcontext().prec = 500
num = Decimal(1) / Decimal(3 ** 5)

## mpmath:
mpmath.mp.dps = 100
num2 = mpmath.mpf(1) / mpmath.mpf(243)

for x in range (1,10):
    num = Decimal(1) / Decimal(3 ** x)
    print("1 / 3 ** {1} = {0}".format(Decimal(num), x))
    ##print(" mpmath: {0}".format(num2))
    
##print("1 / 7 = {0}".format(Decimal(Decimal(1) / Decimal(7)), x))



## This was the example code:
"""
from decimal import Decimal, getcontext
import math

import mpmath

getcontext().prec = 50
mpmath.mp.dps = 50
num = Decimal(1) / Decimal(7)

num2 = mpmath.mpf(1) / mpmath.mpf(7)

print("   math.sqrt: {0}".format(Decimal(math.sqrt(num))))
print("decimal.sqrt: {0}".format(num.sqrt()))
print(" mpmath.sqrt: {0}".format(mpmath.sqrt(num2)))
print('actual value: 0.3779644730092272272145165362341800608157513118689214')
"""
# Out:
# 1 / 243 = ?
# 1 / 3 ** 1 = 0....
# 1 / 3 ** 2 = 0....
# 1 / 3 ** 3 = 0....
# 1 / 3 ** 4 = 0....
# 1 / 3 ** 5 = 0....
# 1 / 3 ** 6 = 0....
# 1 / 3 ** 7 = 0....
# 1 / 3 ** 8 = 0....
# 1 / 3 ** 9 = 0....
# '\nfrom decimal import Decimal, getcontext\nimport math\n\nimport mpmath\n\ngetcontext().prec = 50\nmpmath.mp.dps = 50\nnum = Decimal(1) / Decimal(7)\n\nnum2 = mpmath.mpf(1) / mpmath.mpf(7)\n\nprint("   math.sqrt: {0}".format(Decimal(math.sqrt(num))))\nprint("decimal.sqrt: {0}".format(num.sqrt()))\nprint(" mpmath.sqrt: {0}".format(mpmath.sqrt(num2)))\nprint(\'actual value: 0.3779644730092272272145165362341800608157513118689214\')\n'
