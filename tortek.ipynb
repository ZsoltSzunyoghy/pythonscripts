# %%
#generete fractal exercise

import random

for i in range(100):
    # print(i)
    n = random.randint(2,20)
    a = random.randint(2,20)
    b = random.randint(2,20)
    if(b != n):
        print("mennyi {}-nek a {} / {}-ed része?                            ---{}".format(a*n, b, n,b*a))
# Out:
# mennyi 36-nek a 17 / 12-ed része?                            ---51
# mennyi 154-nek a 10 / 11-ed része?                            ---140
# mennyi 144-nek a 11 / 8-ed része?                            ---198
# mennyi 77-nek a 12 / 7-ed része?                            ---132
# mennyi 6-nek a 18 / 3-ed része?                            ---36
# mennyi 90-nek a 4 / 5-ed része?                            ---72
# mennyi 288-nek a 6 / 18-ed része?                            ---96
# mennyi 102-nek a 7 / 6-ed része?                            ---119
# mennyi 120-nek a 11 / 12-ed része?                            ---110
# mennyi 98-nek a 15 / 7-ed része?                            ---210
# mennyi 114-nek a 7 / 19-ed része?                            ---42
# mennyi 90-nek a 17 / 9-ed része?                            ---170
# mennyi 68-nek a 5 / 4-ed része?                            ---85
# mennyi 56-nek a 2 / 8-ed része?                            ---14
# ...
